# %%
# Genetic Algorithm for mTSP using the flow from Electronics 2024
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tracemalloc
import math
import random

from typing import List, Tuple

SEED = 42  
random.seed(SEED)
np.random.seed(SEED)


class RLGA_mTSP:
    def __init__(self, distance_matrix: np.ndarray, m: int = 3,
                 pop_size: int = 100, generations: int = 300,
                 epsilon: float = 0.1, epsilon_decay: float = 0.99):
        
        self.distance_matrix = distance_matrix
        self.n_cities = len(distance_matrix)
        self.m = m
        self.pop_size = pop_size
        self.generations = generations
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.depot = 0

        self.crossover_rates = [0.7, 0.8, 0.9]
        self.mutation_rates = [0.05, 0.1, 0.15]
        self.Q = {}
        self.current_pc = 0.8
        self.current_pm = 0.1

        self.last_best_fitness = float('inf')

    def initialize_population(self) -> List[List[int]]:
        cities = list(range(1, self.n_cities))
        return [random.sample(cities, len(cities)) for _ in range(self.pop_size)]

    def decode_solution(self, chromosome: List[int]) -> List[List[int]]:
        routes = [[] for _ in range(self.m)]
        for i, city in enumerate(chromosome):
            routes[i % self.m].append(city)
        return routes

    def calculate_fitness(self, chromosome: List[int]) -> float:
        routes = self.decode_solution(chromosome)
        route_distances = [
            sum(self.distance_matrix[route[i]][route[i+1]] for i in range(len(route)-1))
            if len(route) > 1 else 0
            for route in [[self.depot] + r + [self.depot] for r in routes]
        ]
        return max(route_distances) if route_distances else float('inf')

    def tournament_selection(self, population: List[List[int]], fitness: List[float]) -> List[int]:
        i, j, k = random.sample(range(len(population)), 3)
        best_idx = min([i, j, k], key=lambda idx: fitness[idx])
        return population[best_idx].copy()

    def partially_mapped_crossover(self, p1: List[int], p2: List[int]) -> Tuple[List[int], List[int]]:
        if random.random() > self.current_pc:
            return p1.copy(), p2.copy()

        size = len(p1)
        cx_point1, cx_point2 = sorted(random.sample(range(size), 2))
        
        def pmx(parent1, parent2):
            child = [None] * size
            child[cx_point1:cx_point2] = parent1[cx_point1:cx_point2]
            for i in range(cx_point1, cx_point2):
                if parent2[i] not in child:
                    val = parent2[i]
                    idx = i
                    while True:
                        val = parent1[idx]
                        idx = parent2.index(val)
                        if child[idx] is None:
                            child[idx] = parent2[i]
                            break
            for i in range(size):
                if child[i] is None:
                    child[i] = parent2[i]
            return child

        return pmx(p1, p2), pmx(p2, p1)

    def index_mutation(self, chromosome: List[int]) -> List[int]:
        if random.random() < self.current_pm:
            i = random.randint(0, len(chromosome) - 1)
            available_values = [v for v in range(1, self.n_cities) if v not in chromosome or chromosome.index(v) == i]
            if available_values:
                chromosome[i] = random.choice(available_values)
        return chromosome

    def update_q(self, state: str, action: Tuple[float, float], reward: float):
        alpha = 0.1
        if state not in self.Q:
            self.Q[state] = { (pc, pm): 0.0 for pc in self.crossover_rates for pm in self.mutation_rates }
        self.Q[state][action] += alpha * (reward - self.Q[state][action])

    def select_action(self, state: str) -> Tuple[float, float]:
        if state not in self.Q:
            self.Q[state] = { (pc, pm): 0.0 for pc in self.crossover_rates for pm in self.mutation_rates }
        if random.random() < self.epsilon:
            return random.choice(self.crossover_rates), random.choice(self.mutation_rates)
        return max(self.Q[state].items(), key=lambda x: x[1])[0]

    def get_state(self, fitness_list: List[float]) -> str:
        diversity = np.std(fitness_list)
        improvement = self.last_best_fitness - min(fitness_list)
        diversity_level = "high" if diversity > np.mean(fitness_list) * 0.1 else "low"
        improvement_level = "good" if improvement > 0 else "poor"
        return f"{diversity_level}_{improvement_level}"

    def run(self):
        population = self.initialize_population()
        best_solution = None
        best_fitness = float('inf')
        fitness_history = []

        for gen in range(self.generations):
            fitness_scores = [self.calculate_fitness(ind) for ind in population]
            best_idx = np.argmin(fitness_scores)
            if fitness_scores[best_idx] < best_fitness:
                best_fitness = fitness_scores[best_idx]
                best_solution = population[best_idx].copy()

            fitness_history.append(best_fitness)
            state = self.get_state(fitness_scores)
            self.current_pc, self.current_pm = self.select_action(state)

            new_population = []
            elite = population[best_idx].copy()
            new_population.append(elite)

            while len(new_population) < self.pop_size:
                p1 = self.tournament_selection(population, fitness_scores)
                p2 = self.tournament_selection(population, fitness_scores)
                c1, c2 = self.partially_mapped_crossover(p1, p2)
                c1 = self.index_mutation(c1)
                c2 = self.index_mutation(c2)
                new_population.extend([c1, c2])

            population = new_population[:self.pop_size]

            reward = (self.last_best_fitness - best_fitness) / (abs(self.last_best_fitness) + 1e-6)
            self.update_q(state, (self.current_pc, self.current_pm), reward)
            self.last_best_fitness = best_fitness
            self.epsilon *= self.epsilon_decay

            if gen % 20 == 0:
                print(f"Gen {gen}: Best max route length = {best_fitness:.2f}, Pc = {self.current_pc:.2f}, Pm = {self.current_pm:.2f}")

        routes = self.decode_solution(best_solution)
        route_distances = [
            sum(self.distance_matrix[r[i]][r[i+1]] for i in range(len(r)-1))
            for r in [[self.depot] + route + [self.depot] for route in routes]
        ]
        total_distance = sum(route_distances)
        balance_metric = max(route_distances) - min(route_distances) if route_distances else 0

        return routes, total_distance, best_fitness, balance_metric, fitness_history
    
def detect_convergence(fitness_list, window=5, threshold=1e-3):
    """Detect convergence in fitness evolution"""
    if len(fitness_list) < window:
        return len(fitness_list)
    for i in range(len(fitness_list) - window):
        if abs(fitness_list[i] - fitness_list[i + window]) < threshold:
            return i + window
    return len(fitness_list)


# Load real distance matrix or create example
try:
    distance_df = pd.read_csv('../data/HN_distance_matrix.csv', index_col=0)
    distance_matrix = distance_df.values
    print("Loaded real distance matrix")
except:
    # Fallback to example matrix
    n_cities = 127
    rng = np.random.default_rng(42)
    distance_matrix = rng.uniform(10, 100, size=(n_cities, n_cities))
    distance_matrix = (distance_matrix + distance_matrix.T) / 2
    np.fill_diagonal(distance_matrix, 0)
    print("Using example distance matrix")

print("Số thành phố:", distance_matrix.shape[0])
print("Ví dụ khoảng cách [0][1]:", distance_matrix[0][1])
# Out:
# Loaded real distance matrix
# Số thành phố: 127
# Ví dụ khoảng cách [0][1]: 21.48

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

# --- CẤU HÌNH ---
N_TRIALS = 20  # Số lần chạy mỗi kịch bản
m_values = range(1, 4) # Số người bán hàng m = 1, 2, 3

# Tên file lưu trữ
detail_file = "results_details_rlga.csv"    # Lưu chi tiết 60 dòng (3m * 20 run)
stats_file = "results_stats_rlga.csv"       # Lưu thống kê tổng hợp (Mean/Std)

# Các chỉ số cần theo dõi
metrics = [
    "total_distance", "fitness", "balance_metric", 
    "exec_time", "converged_gen", "convergence_speed"
]

# 1. Tạo file rỗng chứa header cho file chi tiết
pd.DataFrame(columns=["m", "trial"] + metrics).to_csv(detail_file, index=False)

# 2. Tạo file rỗng chứa header cho file thống kê
stats_cols = ["m"] + [f"{col}_mean" for col in metrics] + [f"{col}_std" for col in metrics]
pd.DataFrame(columns=stats_cols).to_csv(stats_file, index=False)

# --- VÒNG LẶP CHÍNH ---
for m in m_values:
    print(f"\n{'='*10} RLGA - Số người (m) = {m} | Chạy {N_TRIALS} lần {'='*10}")
    
    trial_results = []       # Danh sách lưu kết quả các lần chạy để tính toán sau
    all_fitness_history = [] # Danh sách lưu lịch sử fitness để vẽ biểu đồ

    for trial in range(1, N_TRIALS + 1):
        # --- BẮT ĐẦU ĐO LƯỜNG ---
        start_time = time.time()
        
        # Khởi tạo và chạy thuật toán RLGA
        # Lưu ý: Class RLGA_mTSP phải được định nghĩa trước đó
        rlga = RLGA_mTSP(distance_matrix, m=m, pop_size=100, generations=300)
        routes, total_distance, max_route, balance_metric, fitness_per_generation = rlga.run()
        
        end_time = time.time()
        exec_time = end_time - start_time

        # --- TÍNH TOÁN LẠI CHỈ SỐ (Để đảm bảo chính xác) ---
        route_distances = []
        for route in routes:
            if len(route) > 0:
                full_route = [0] + route + [0]
                distance = sum(distance_matrix[full_route[i]][full_route[i+1]] 
                               for i in range(len(full_route)-1))
                route_distances.append(distance)
            else:
                route_distances.append(0)

        # Tính Balance metric (Chênh lệch Max - Min)
        balance_metric = max(route_distances) - min(route_distances) if route_distances else 0

        # Phân tích hội tụ
        converged_gen = detect_convergence(fitness_per_generation)
        convergence_speed = (fitness_per_generation[0] - fitness_per_generation[-1]) / converged_gen if converged_gen > 0 else 0

        # --- LƯU KẾT QUẢ TRIAL NÀY ---
        row = {
            "m": m,
            "trial": trial,
            "total_distance": total_distance,
            "fitness": max_route, # Trong bài toán này max_route đóng vai trò fitness
            "balance_metric": balance_metric,
            "exec_time": exec_time,
            "converged_gen": converged_gen,
            "convergence_speed": convergence_speed
        }
        trial_results.append(row)
        all_fitness_history.append(fitness_per_generation)

        # Ghi ngay vào file chi tiết (append mode)
        pd.DataFrame([row]).to_csv(detail_file, mode="a", index=False, header=False)
        
        # In tiến độ gọn gàng (Overwrite dòng cũ để không rối mắt)
        print(f"\r -> Trial {trial}/{N_TRIALS}: Fitness={max_route:.2f}, Time={exec_time:.2f}s", end="")

    print(f"\n   [Hoàn thành {N_TRIALS} lần chạy cho m={m}]")

    # --- TÍNH TOÁN THỐNG KÊ (MEAN & STD) ---
    df_trials = pd.DataFrame(trial_results)
    stats_row = {"m": m}
    
    for col in metrics:
        stats_row[f"{col}_mean"] = df_trials[col].mean()
        stats_row[f"{col}_std"] = df_trials[col].std() # Độ lệch chuẩn
    
    # Lưu vào file thống kê
    pd.DataFrame([stats_row]).to_csv(stats_file, mode="a", index=False, header=False)

    # Hiển thị báo cáo nhanh ra màn hình
    print(f"   => Trung bình Fitness: {stats_row['fitness_mean']:.2f} (±{stats_row['fitness_std']:.2f})")
    print(f"   => Trung bình Balance: {stats_row['balance_metric_mean']:.2f}")
    print(f"   => Trung bình Thời gian: {stats_row['exec_time_mean']:.4f}s")

    # --- VẼ BIỂU ĐỒ FITNESS TRUNG BÌNH ---
    # Padding dữ liệu nếu độ dài các lần chạy không đều nhau
    max_len = max(len(h) for h in all_fitness_history)
    padded_history = []
    for h in all_fitness_history:
        # Điền nốt các giá trị cuối cùng cho đến khi bằng độ dài max
        padded = h + [h[-1]] * (max_len - len(h))
        padded_history.append(padded)
    
    # Tính trung bình dọc theo trục dọc (axis=0)
    avg_fitness_curve = np.mean(padded_history, axis=0)

    plt.figure(figsize=(10, 5))
    # Vẽ các đường mờ (từng lần chạy lẻ)
    for h in all_fitness_history:
        plt.plot(h, color='salmon', alpha=0.3, linewidth=0.5) # Màu salmon nhạt cho RLGA
    # Vẽ đường trung bình đậm
    plt.plot(avg_fitness_curve, color='red', linewidth=2, label='Average Fitness (20 runs)')
    
    plt.title(f"RLGA Convergence - Average over {N_TRIALS} runs (m={m})")
    plt.xlabel("Generation")
    plt.ylabel("Fitness (Max Route Length)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

print("\n=== HOÀN TẤT THỰC NGHIỆM RLGA ===")
# Out:
# ========== RLGA - Số người (m) = 1 | Chạy 20 lần ==========
# Gen 0: Best max route length = 1649.13, Pc = 0.80, Pm = 0.05
# C:\Users\vthuy\AppData\Local\Temp\ipykernel_12412\814431389.py:149: RuntimeWarning: invalid value encountered in scalar divide
#   reward = (self.last_best_fitness - best_fitness) / (abs(self.last_best_fitness) + 1e-6)
# Gen 20: Best max route length = 1343.90, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
#  -> Trial 1/20: Fitness=1290.72, Time=6.25sGen 0: Best max route length = 1629.37, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1333.68, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1233.60, Pc = 0.70, Pm = 0.05
#  -> Trial 2/20: Fitness=1233.60, Time=5.27sGen 0: Best max route length = 1555.87, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1285.47, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1263.25, Pc = 0.70, Pm = 0.05
#  -> Trial 3/20: Fitness=1263.25, Time=3.81sGen 0: Best max route length = 1601.19, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1368.68, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1349.00, Pc = 0.70, Pm = 0.05
#  -> Trial 4/20: Fitness=1349.00, Time=3.79sGen 0: Best max route length = 1642.56, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1351.77, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1313.99, Pc = 0.70, Pm = 0.05
#  -> Trial 5/20: Fitness=1313.99, Time=3.36sGen 0: Best max route length = 1605.12, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1300.31, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1233.39, Pc = 0.80, Pm = 0.10
# Gen 280: Best max route length = 1233.39, Pc = 0.70, Pm = 0.05
#  -> Trial 6/20: Fitness=1233.39, Time=4.26sGen 0: Best max route length = 1603.89, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1328.47, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1257.90, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1257.90, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1257.90, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1257.90, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1257.90, Pc = 0.90, Pm = 0.10
# Gen 140: Best max route length = 1257.90, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1257.90, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1257.90, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1257.90, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1257.90, Pc = 0.90, Pm = 0.15
# Gen 240: Best max route length = 1257.90, Pc = 0.80, Pm = 0.05
# Gen 260: Best max route length = 1257.90, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1257.90, Pc = 0.70, Pm = 0.05
#  -> Trial 7/20: Fitness=1257.90, Time=4.26sGen 0: Best max route length = 1598.82, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1323.88, Pc = 0.90, Pm = 0.10
# Gen 40: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1293.89, Pc = 0.70, Pm = 0.05
#  -> Trial 8/20: Fitness=1293.89, Time=3.57sGen 0: Best max route length = 1622.73, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1375.64, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1278.36, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1262.94, Pc = 0.70, Pm = 0.05
#  -> Trial 9/20: Fitness=1262.94, Time=3.40sGen 0: Best max route length = 1634.39, Pc = 0.80, Pm = 0.10
# Gen 20: Best max route length = 1375.69, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1316.70, Pc = 0.70, Pm = 0.05
#  -> Trial 10/20: Fitness=1316.70, Time=4.56sGen 0: Best max route length = 1634.51, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1338.58, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1159.54, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1158.80, Pc = 0.70, Pm = 0.05
#  -> Trial 11/20: Fitness=1158.80, Time=3.91sGen 0: Best max route length = 1594.59, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1291.14, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1189.96, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1184.89, Pc = 0.70, Pm = 0.05
#  -> Trial 12/20: Fitness=1184.89, Time=3.55sGen 0: Best max route length = 1612.75, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1328.20, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1318.01, Pc = 0.70, Pm = 0.15
# Gen 240: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1318.01, Pc = 0.70, Pm = 0.05
#  -> Trial 13/20: Fitness=1318.01, Time=3.27sGen 0: Best max route length = 1631.72, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1315.55, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1181.35, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1180.10, Pc = 0.70, Pm = 0.10
# Gen 80: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1180.10, Pc = 0.70, Pm = 0.05
#  -> Trial 14/20: Fitness=1180.10, Time=3.26sGen 0: Best max route length = 1616.71, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1334.05, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1302.00, Pc = 0.70, Pm = 0.05
#  -> Trial 15/20: Fitness=1302.00, Time=3.90sGen 0: Best max route length = 1625.29, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1331.04, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1261.95, Pc = 0.70, Pm = 0.15
# Gen 60: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1261.95, Pc = 0.70, Pm = 0.05
#  -> Trial 16/20: Fitness=1261.95, Time=4.49sGen 0: Best max route length = 1597.29, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1373.34, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1355.43, Pc = 0.70, Pm = 0.05
#  -> Trial 17/20: Fitness=1355.43, Time=3.98sGen 0: Best max route length = 1620.23, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1342.04, Pc = 0.70, Pm = 0.05
#  -> Trial 18/20: Fitness=1342.04, Time=3.41sGen 0: Best max route length = 1634.82, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1390.46, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1389.05, Pc = 0.70, Pm = 0.05
#  -> Trial 19/20: Fitness=1389.05, Time=3.81sGen 0: Best max route length = 1585.00, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 1303.72, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1262.41, Pc = 0.70, Pm = 0.15
# Gen 60: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1262.41, Pc = 0.70, Pm = 0.05
#  -> Trial 20/20: Fitness=1262.41, Time=4.58s
#    [Hoàn thành 20 lần chạy cho m=1]
#    => Trung bình Fitness: 1278.50 (±60.97)
#    => Trung bình Balance: 0.00
#    => Trung bình Thời gian: 4.0347s
# ========== RLGA - Số người (m) = 2 | Chạy 20 lần ==========
# Gen 0: Best max route length = 868.34, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 760.04, Pc = 0.80, Pm = 0.15
# Gen 40: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 759.84, Pc = 0.80, Pm = 0.05
# Gen 220: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 759.84, Pc = 0.70, Pm = 0.05
#  -> Trial 1/20: Fitness=759.84, Time=5.36sGen 0: Best max route length = 816.16, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 730.49, Pc = 0.70, Pm = 0.05
#  -> Trial 2/20: Fitness=730.49, Time=5.34sGen 0: Best max route length = 849.75, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 754.04, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 740.14, Pc = 0.90, Pm = 0.15
# Gen 60: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 740.14, Pc = 0.70, Pm = 0.05
#  -> Trial 3/20: Fitness=740.14, Time=3.85sGen 0: Best max route length = 852.89, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 717.66, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 683.36, Pc = 0.70, Pm = 0.05
#  -> Trial 4/20: Fitness=683.36, Time=3.85sGen 0: Best max route length = 871.28, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 755.60, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 746.40, Pc = 0.70, Pm = 0.05
#  -> Trial 5/20: Fitness=746.40, Time=3.65sGen 0: Best max route length = 874.53, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 703.96, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 687.82, Pc = 0.70, Pm = 0.05
#  -> Trial 6/20: Fitness=687.82, Time=4.09sGen 0: Best max route length = 859.71, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 735.05, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 698.65, Pc = 0.70, Pm = 0.05
#  -> Trial 7/20: Fitness=698.65, Time=3.38sGen 0: Best max route length = 854.21, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 738.29, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 718.85, Pc = 0.70, Pm = 0.05
#  -> Trial 8/20: Fitness=718.85, Time=3.79sGen 0: Best max route length = 843.16, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 720.64, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 719.11, Pc = 0.70, Pm = 0.05
#  -> Trial 9/20: Fitness=719.11, Time=5.59sGen 0: Best max route length = 842.11, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 717.17, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 679.28, Pc = 0.70, Pm = 0.05
#  -> Trial 10/20: Fitness=679.28, Time=3.20sGen 0: Best max route length = 842.85, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 753.57, Pc = 0.70, Pm = 0.05
#  -> Trial 11/20: Fitness=753.57, Time=3.81sGen 0: Best max route length = 868.50, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 729.28, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 714.29, Pc = 0.70, Pm = 0.05
#  -> Trial 12/20: Fitness=714.29, Time=4.03sGen 0: Best max route length = 849.96, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 717.32, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 687.33, Pc = 0.80, Pm = 0.10
# Gen 80: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 687.33, Pc = 0.70, Pm = 0.05
#  -> Trial 13/20: Fitness=687.33, Time=3.14sGen 0: Best max route length = 845.78, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 723.42, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 721.66, Pc = 0.70, Pm = 0.05
#  -> Trial 14/20: Fitness=721.66, Time=2.97sGen 0: Best max route length = 848.49, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 755.63, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 704.51, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 702.82, Pc = 0.80, Pm = 0.05
# Gen 120: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 702.82, Pc = 0.70, Pm = 0.05
#  -> Trial 15/20: Fitness=702.82, Time=3.49sGen 0: Best max route length = 845.07, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 709.33, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 695.49, Pc = 0.70, Pm = 0.05
#  -> Trial 16/20: Fitness=695.49, Time=3.18sGen 0: Best max route length = 844.88, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 737.48, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 731.25, Pc = 0.70, Pm = 0.05
#  -> Trial 17/20: Fitness=731.25, Time=2.87sGen 0: Best max route length = 851.37, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 748.27, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 727.67, Pc = 0.70, Pm = 0.05
#  -> Trial 18/20: Fitness=727.67, Time=3.29sGen 0: Best max route length = 860.78, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 771.11, Pc = 0.90, Pm = 0.10
# Gen 60: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 771.11, Pc = 0.70, Pm = 0.05
#  -> Trial 19/20: Fitness=771.11, Time=3.21sGen 0: Best max route length = 846.27, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 691.38, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 680.88, Pc = 0.90, Pm = 0.10
# Gen 200: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 680.88, Pc = 0.70, Pm = 0.05
#  -> Trial 20/20: Fitness=680.88, Time=3.91s
#    [Hoàn thành 20 lần chạy cho m=2]
#    => Trung bình Fitness: 717.50 (±27.74)
#    => Trung bình Balance: 5.25
#    => Trung bình Thời gian: 3.7999s
# ========== RLGA - Số người (m) = 3 | Chạy 20 lần ==========
# Gen 0: Best max route length = 590.90, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 531.65, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 526.91, Pc = 0.70, Pm = 0.10
# Gen 60: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 526.91, Pc = 0.70, Pm = 0.05
#  -> Trial 1/20: Fitness=526.91, Time=3.86sGen 0: Best max route length = 610.06, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 538.14, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 532.96, Pc = 0.70, Pm = 0.05
#  -> Trial 2/20: Fitness=532.96, Time=4.45sGen 0: Best max route length = 607.02, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 551.08, Pc = 0.70, Pm = 0.05
#  -> Trial 3/20: Fitness=551.08, Time=4.90sGen 0: Best max route length = 590.87, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 531.12, Pc = 0.80, Pm = 0.05
# Gen 40: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 521.90, Pc = 0.70, Pm = 0.05
#  -> Trial 4/20: Fitness=521.90, Time=3.01sGen 0: Best max route length = 609.45, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 521.29, Pc = 0.70, Pm = 0.15
# Gen 40: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 516.28, Pc = 0.70, Pm = 0.05
#  -> Trial 5/20: Fitness=516.28, Time=3.29sGen 0: Best max route length = 593.42, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 522.64, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 521.57, Pc = 0.90, Pm = 0.05
# Gen 60: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 521.57, Pc = 0.70, Pm = 0.05
#  -> Trial 6/20: Fitness=521.57, Time=3.34sGen 0: Best max route length = 601.92, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 541.86, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 535.05, Pc = 0.70, Pm = 0.05
#  -> Trial 7/20: Fitness=535.05, Time=3.14sGen 0: Best max route length = 610.74, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 512.74, Pc = 0.90, Pm = 0.10
# Gen 40: Best max route length = 467.13, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 466.86, Pc = 0.70, Pm = 0.05
#  -> Trial 8/20: Fitness=466.86, Time=3.79sGen 0: Best max route length = 585.70, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 538.37, Pc = 0.70, Pm = 0.10
# Gen 40: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 538.37, Pc = 0.70, Pm = 0.05
#  -> Trial 9/20: Fitness=538.37, Time=2.94sGen 0: Best max route length = 608.87, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 536.29, Pc = 0.70, Pm = 0.05
#  -> Trial 10/20: Fitness=536.29, Time=3.11sGen 0: Best max route length = 595.32, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 522.35, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 499.60, Pc = 0.70, Pm = 0.05
#  -> Trial 11/20: Fitness=499.60, Time=3.10sGen 0: Best max route length = 577.72, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 529.30, Pc = 0.90, Pm = 0.15
# Gen 40: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 529.30, Pc = 0.70, Pm = 0.05
#  -> Trial 12/20: Fitness=529.30, Time=2.89sGen 0: Best max route length = 599.35, Pc = 0.70, Pm = 0.15
# Gen 20: Best max route length = 496.48, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 493.41, Pc = 0.90, Pm = 0.05
# Gen 60: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 493.41, Pc = 0.70, Pm = 0.05
#  -> Trial 13/20: Fitness=493.41, Time=3.13sGen 0: Best max route length = 603.54, Pc = 0.90, Pm = 0.15
# Gen 20: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 566.20, Pc = 0.70, Pm = 0.15
# Gen 60: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 566.20, Pc = 0.70, Pm = 0.05
#  -> Trial 14/20: Fitness=566.20, Time=3.37sGen 0: Best max route length = 574.62, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 537.15, Pc = 0.70, Pm = 0.05
#  -> Trial 15/20: Fitness=537.15, Time=3.17sGen 0: Best max route length = 595.20, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 537.60, Pc = 0.70, Pm = 0.05
#  -> Trial 16/20: Fitness=537.60, Time=3.43sGen 0: Best max route length = 622.26, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 535.71, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 534.99, Pc = 0.70, Pm = 0.05
#  -> Trial 17/20: Fitness=534.99, Time=3.82sGen 0: Best max route length = 618.84, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 533.48, Pc = 0.70, Pm = 0.05
#  -> Trial 18/20: Fitness=533.48, Time=4.33sGen 0: Best max route length = 613.67, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 545.27, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 541.97, Pc = 0.70, Pm = 0.05
#  -> Trial 19/20: Fitness=541.97, Time=3.50sGen 0: Best max route length = 608.63, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 552.10, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 550.88, Pc = 0.70, Pm = 0.05
#  -> Trial 20/20: Fitness=550.88, Time=3.84s
#    [Hoàn thành 20 lần chạy cho m=3]
#    => Trung bình Fitness: 528.59 (±21.97)
#    => Trung bình Balance: 9.00
#    => Trung bình Thời gian: 3.5211s
# === HOÀN TẤT THỰC NGHIỆM RLGA ===

# %% [markdown]
# end

# %%
# File tổng hợp kết quả
summary_file = "results_summary_rlga.csv"
summary_cols = [
    "m", "total_distance", "fitness", "balance_metric",
    "exec_time", "converged_gen", "convergence_speed"
]

# Run experiments for different numbers of salesmen
for m in range(1, 4):
    print(f"\n=== RLGA - Số người bán hàng (m) = {m} ===")

    start_time = time.time()

    rlga = RLGA_mTSP(distance_matrix, m=m, pop_size=100, generations=300)
    routes, total_distance, max_route, balance_metric, fitness_per_generation = rlga.run()

    end_time = time.time()
    exec_time = end_time - start_time

    # Tính khoảng cách từng route
    route_distances = []
    for route in routes:
        if len(route) > 0:
            full_route = [0] + route + [0]
            distance = sum(distance_matrix[full_route[i]][full_route[i+1]] 
                           for i in range(len(full_route)-1))
            route_distances.append(distance)
        else:
            route_distances.append(0)

    # Chênh lệch giữa các route
    balance_metric = max(route_distances) - min(route_distances) if route_distances else 0

    # Phân tích hội tụ
    converged_gen = detect_convergence(fitness_per_generation)
    convergence_speed = (fitness_per_generation[0] - fitness_per_generation[-1]) / converged_gen if converged_gen > 0 else 0

    # In kết quả
    print(f"Tổng quãng đường: {total_distance:.2f}")
    print(f"Chiều dài route dài nhất (Max route length): {max_route:.2f}")
    print(f"Chênh lệch giữa các route (Balance metric): {balance_metric:.2f}")
    print(f"Thời gian thực thi: {exec_time:.4f} giây")
    print(f"Số vòng lặp cần thiết để hội tụ: {converged_gen}")
    print(f"Tốc độ hội tụ: {convergence_speed:.4f} đơn vị/gen")

    # Hiển thị từng route
    for i, route in enumerate(routes):
        if len(route) > 0:
            full_route = [0] + route + [0]
            print(f" - Tuyến {i+1} ({route_distances[i]:.2f}): {full_route}")
        else:
            print(f" - Tuyến {i+1} (0.00): [0]")

    # === Lưu file tổng hợp ===
    row = {
        "m": m,
        "total_distance": total_distance,
        "fitness": max_route,
        "balance_metric": balance_metric,
        "exec_time": exec_time,
        "converged_gen": converged_gen,
        "convergence_speed": convergence_speed
    }
    pd.DataFrame([row]).to_csv(summary_file, mode="a", index=False, header=False)

    # === Lưu fitness_per_generation riêng ===
    fitness_file = f"rlga_fitness_m{m}.csv"
    pd.DataFrame({
        "generation": range(len(fitness_per_generation)),
        "fitness": fitness_per_generation
    }).to_csv(fitness_file, index=False)

    # Vẽ biểu đồ fitness
    plt.figure(figsize=(10, 6))
    plt.plot(fitness_per_generation, marker='o', linestyle='-', color='red', markersize=3)
    plt.title(f"RLGA - Fitness qua các thế hệ (m = {m})")
    plt.xlabel("Thế hệ")
    plt.ylabel("Max route length (fitness)")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
# Out:
# === RLGA - Số người bán hàng (m) = 1 ===
# Gen 0: Best max route length = 1649.13, Pc = 0.80, Pm = 0.05
# C:\Users\vthuy\AppData\Local\Temp\ipykernel_33008\814431389.py:149: RuntimeWarning: invalid value encountered in scalar divide
#   reward = (self.last_best_fitness - best_fitness) / (abs(self.last_best_fitness) + 1e-6)
# Gen 20: Best max route length = 1343.90, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 1290.72, Pc = 0.70, Pm = 0.05
# Tổng quãng đường: 1290.72
# Chiều dài route dài nhất (Max route length): 1290.72
# Chênh lệch giữa các route (Balance metric): 0.00
# Thời gian thực thi: 3.7070 giây
# Số vòng lặp cần thiết để hội tụ: 35
# Tốc độ hội tụ: 10.2403 đơn vị/gen
#  - Tuyến 1 (1290.72): [0, 95, 25, 36, 110, 24, 122, 108, 106, 38, 98, 118, 80, 74, 51, 67, 69, 52, 34, 102, 112, 113, 75, 93, 104, 121, 22, 124, 5, 85, 35, 116, 23, 20, 16, 105, 15, 88, 77, 30, 91, 50, 7, 103, 115, 83, 126, 40, 119, 109, 87, 14, 17, 94, 64, 8, 12, 97, 18, 70, 107, 117, 96, 48, 68, 53, 41, 79, 19, 120, 55, 44, 76, 62, 66, 49, 99, 57, 78, 33, 58, 81, 100, 123, 125, 32, 56, 10, 9, 37, 90, 42, 60, 111, 21, 71, 45, 46, 54, 6, 63, 86, 39, 31, 26, 29, 89, 4, 73, 3, 61, 2, 92, 13, 72, 47, 65, 82, 84, 27, 101, 43, 11, 28, 114, 1, 59, 0]
# === RLGA - Số người bán hàng (m) = 2 ===
# Gen 0: Best max route length = 856.47, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 753.15, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 727.82, Pc = 0.70, Pm = 0.05
# Tổng quãng đường: 1452.32
# Chiều dài route dài nhất (Max route length): 727.82
# Chênh lệch giữa các route (Balance metric): 3.32
# Thời gian thực thi: 3.9463 giây
# Số vòng lặp cần thiết để hội tụ: 37
# Tốc độ hội tụ: 3.4770 đơn vị/gen
#  - Tuyến 1 (724.50): [0, 96, 62, 35, 65, 102, 91, 116, 27, 82, 84, 41, 46, 58, 60, 13, 38, 25, 83, 59, 33, 121, 115, 14, 76, 56, 11, 12, 126, 45, 6, 26, 55, 114, 3, 77, 92, 20, 8, 93, 10, 32, 24, 89, 97, 19, 61, 63, 36, 48, 74, 110, 66, 1, 86, 15, 79, 34, 53, 2, 111, 108, 5, 50, 0]
#  - Tuyến 2 (727.82): [0, 54, 4, 75, 101, 100, 49, 70, 47, 43, 72, 7, 87, 52, 105, 21, 17, 64, 80, 103, 39, 120, 73, 16, 113, 69, 31, 112, 71, 44, 119, 107, 123, 99, 106, 125, 40, 42, 57, 118, 117, 37, 124, 28, 22, 81, 78, 98, 30, 29, 68, 18, 88, 23, 122, 90, 104, 94, 9, 67, 85, 51, 109, 95, 0]
# === RLGA - Số người bán hàng (m) = 3 ===
# Gen 0: Best max route length = 605.86, Pc = 0.70, Pm = 0.05
# Gen 20: Best max route length = 536.88, Pc = 0.70, Pm = 0.05
# Gen 40: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 60: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 80: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 100: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 120: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 140: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 160: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 180: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 200: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 220: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 240: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 260: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Gen 280: Best max route length = 531.24, Pc = 0.70, Pm = 0.05
# Tổng quãng đường: 1590.13
# Chiều dài route dài nhất (Max route length): 531.24
# Chênh lệch giữa các route (Balance metric): 3.02
# Thời gian thực thi: 3.8064 giây
# Số vòng lặp cần thiết để hội tụ: 26
# Tốc độ hội tụ: 2.8700 đơn vị/gen
#  - Tuyến 1 (530.67): [0, 107, 63, 90, 55, 117, 113, 27, 77, 71, 21, 66, 102, 33, 94, 106, 59, 10, 14, 91, 67, 116, 110, 125, 123, 41, 22, 86, 122, 120, 29, 79, 52, 12, 112, 111, 18, 68, 75, 108, 80, 84, 126, 0]
#  - Tuyến 2 (531.24): [0, 40, 98, 32, 31, 6, 15, 61, 13, 53, 104, 85, 82, 20, 25, 50, 45, 96, 81, 83, 30, 73, 78, 1, 69, 19, 4, 60, 24, 95, 48, 23, 49, 46, 8, 47, 105, 76, 109, 36, 99, 89, 43, 0]
#  - Tuyến 3 (528.22): [0, 114, 35, 121, 37, 101, 119, 38, 97, 65, 62, 3, 54, 5, 64, 39, 88, 44, 57, 74, 56, 92, 28, 70, 9, 7, 26, 115, 11, 118, 17, 2, 93, 58, 51, 42, 72, 16, 103, 87, 34, 100, 124, 0]
