# %%
# %cd /kaggle/working
# !git clone https://github.com/ThuyTien1209/m.git
# Out:
# /kaggle/working
# Cloning into 'm'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 58 (delta 13), reused 17 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 920.65 KiB | 8.85 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# !ls /kaggle/working
# Out:
# m  __notebook__.ipynb

# %%
# %cd /kaggle/working/m/algorithm
# Out:
# /kaggle/working/m/algorithm

# %%
# %run ga_combine.ipynb
# Out:
# Số thành phố: 127
# Ví dụ khoảng cách [0][1]: 20.32
#
# ========== Số người (m) = 1 | Chạy 20 lần ==========
# ...
# 100%|█████████████████████████████████████████| 300/300 [01:36<00:00,  3.11it/s]
#    [Hoàn thành 20 lần chạy cho m=1]
#    => Trung bình Dist: 585.35 (±81.31)
#    => Trung bình Time: 97.4108s
#    => Trung bình Balance: 0.00
# ========== Số người (m) = 2 | Chạy 20 lần ==========
# ...
# 100%|█████████████████████████████████████████| 300/300 [01:39<00:00,  3.01it/s]
#    [Hoàn thành 20 lần chạy cho m=2]
#    => Trung bình Dist: 833.43 (±39.48)
#    => Trung bình Time: 101.7147s
#    => Trung bình Balance: 4.19
# ========== Số người (m) = 3 | Chạy 20 lần ==========
# ...
# 100%|█████████████████████████████████████████| 300/300 [01:42<00:00,  2.93it/s]
#    [Hoàn thành 20 lần chạy cho m=3]
#    => Trung bình Dist: 972.62 (±23.46)
#    => Trung bình Time: 106.0291s
#    => Trung bình Balance: 7.60
# === HOÀN TẤT TOÀN BỘ QUÁ TRÌNH ===
#
# === Số người (m) = 1 ===
# ...

# %%
pd.read_csv("/kaggle/working/m/algorithm/results_stats_summary.csv")
# Out:
#    m  total_distance_mean  fitness_mean  balance_metric_mean  exec_time_mean  \
# 0  1             585.3545     81.313099             585.3545       81.313099
# 1  2             833.4340     39.484661             419.9620       19.861566
# 2  3             972.6160     23.456885             328.8640        7.977947
#
#    memory_current_MB_mean  memory_peak_MB_mean  converged_gen_mean  \
# 0                   0.000             0.000000           97.410800
# 1                   4.192             3.277531          101.714657
# 2                   7.601             6.204307          106.029091
#
#    convergence_speed_mean  total_distance_std  fitness_std  \
# 0                0.574721            0.460877     0.084254
# 1                0.516867            0.543051     0.078858
# 2                0.463935            0.645897     0.065849
#
#    balance_metric_std  exec_time_std  memory_current_MB_std  \
# 0            1.151283       0.076438                  23.70
# ...

# %%
pd.read_csv("/kaggle/working/m/algorithm/results_details_20runs.csv").head()
# Out:
#    m  trial  total_distance  fitness  balance_metric  exec_time  \
# 0  1      1          613.61   613.61             0.0  96.961566
# 1  1      2          618.36   618.36             0.0  97.317899
# 2  1      3          633.26   633.26             0.0  97.947603
# 3  1      4          513.75   513.75             0.0  97.193184
# 4  1      5          451.18   451.18             0.0  97.553041
#
#    memory_current_MB  memory_peak_MB  converged_gen  convergence_speed
# 0           0.666075        1.355380             35          18.034571
# 1           0.365303        1.086087             22          26.865455
# 2           0.415776        1.078253             39          16.541282
# 3           0.406974        1.079595             16          46.105625
# 4           0.397806        1.099515             20          40.621500

# %%
from IPython.display import FileLink
FileLink('/kaggle/working/m/algorithm/results_details_20runs.csv')
# Out:
# /kaggle/working/m/algorithm/results_details_20runs.csv

# %%
# %cd /kaggle/working/m/algorithm
# !ls
# Out:
# /kaggle/working/m/algorithm
# ga_combine_fitness_m1.csv   results_details_rlga.csv
# ga_combine_fitness_m2.csv   results_raw_details.csv
# ga_combine_fitness_m3.csv   results_stats_rlga.csv
# ga_combine.ipynb	    results_stats_summary.csv
# ga_local_search.ipynb	    results_summary_ga_combine.csv
# gasa_section.ipynb	    results_summary_ga_goc.csv
# results_details_20runs.csv  results_summary_gasa.csv
# results_details_ga_goc.csv  results_summary_ga_stats.csv
# results_details_gasa.csv    rlga.ipynb

# %%
# %run ga_local_search.ipynb
# Out:
# Số thành phố: 127
# Ví dụ khoảng cách [0][1]: 20.32
#
# ========== GA Gốc - Số người (m) = 1 | Chạy 20 lần ==========
# 100%|█████████████████████████████████████████| 300/300 [01:36<00:00,  3.11it/s]
#  -> Trial 1/20: Fitness=693.82, Time=97.48s
# 100%|█████████████████████████████████████████| 300/300 [01:35<00:00,  3.13it/s]
#  -> Trial 2/20: Fitness=691.19, Time=96.84s
# 100%|█████████████████████████████████████████| 300/300 [01:34<00:00,  3.16it/s]
#  -> Trial 3/20: Fitness=462.97, Time=96.01s
# 100%|█████████████████████████████████████████| 300/300 [01:35<00:00,  3.13it/s]
#  -> Trial 4/20: Fitness=494.32, Time=96.90s
# 100%|█████████████████████████████████████████| 300/300 [01:35<00:00,  3.14it/s]
#  -> Trial 5/20: Fitness=509.99, Time=96.68s
# 100%|█████████████████████████████████████████| 300/300 [01:35<00:00,  3.14it/s]
#  -> Trial 6/20: Fitness=711.28, Time=96.56s
# 100%|█████████████████████████████████████████| 300/300 [01:35<00:00,  3.14it/s]
# ...
